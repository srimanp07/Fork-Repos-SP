# %% [markdown]
# # DEF-D Fysieke Ontwerpopdracht 5 Invul template

# %% [markdown]
# ## Groep informatie
#
# Aan het einde van deze ontwerpopdracht lever je als groep één gezamenlijk notebook in. Zet jullie studienummers en namen in onderstaande tabel zodat wij zeker weten dat het groepsvormen goed is gegaan.

# %% [markdown]
# | Groep: 22     |  |
# | :-------------|:-------------|
# | Sriman Patlolla| 6393829 |
# | Carice von Morgen| 6452892|
# | Zahra Ramdane | 6533183 |

# %% [markdown]
# ## Opdracht 1: Planning.

# %% [markdown]
# | Planning Groep: 22     |Tijdstip / Tijdspanne  | door wie  |
# |---|---|---|
# | Arduino testen| 12.30 | Carice |
# | ontwerp-eis berekenen| 12.30 | Sriman en Zahra|
# | deltax kiezen en bijbehorende parameteres massa en veerconstante kiezen |14.00 | hele groep |
# | simultaie en fabricage | 14.45 | hele groep |
# | eerste metingen vastgelegd | 15.30|hele groep|

# %% [markdown]
# Run onderstaande cel om alle benodigde libraries te laden. Mogelijk voeg je er zelf nog een aantal toe later vandaag.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import random
import time
import math

# %% [markdown]
# ## Opdracht 2a: Opsplitsen taak 1: Arduino
# Vul onderstaande tabel in:

# %% [markdown]
# | onderwerp    | antwoord  |
# |---|---|
# | hoe moeilijk (schaal 1 - 10) | 5 |
# | hoe lang voor één meting | 10 s |
# | verwacht nauwkeurigheid meting | 0.1 |

# %% [markdown]
# ## Opdracht 2b: Opsplitsen taak 2: afleiding ontwerpeis

# %%
# Bereken hier je benodigde kantelfrequentie

#Omschrijven van V=1/(1-(fv/fm)**2) naar fm=... en V=1/3 en w/w0 wordt f/f0 doordat de 2pi wegvallen. f=5 Hz
#Daar uit komt fm=root(25/4)

# %%
# Opdracht 2: 

f_eigenfrequentie =  5/2

f_vloer = np.linspace(0.1, 100, 1000) #Hz

#overdracht formule: 

overdrachtminimaal = np.abs(1 / (1 - (f_vloer/f_eigenfrequentie)**2))

plt.plot(f_vloer, overdrachtminimaal)

plt.xscale('log')
plt.yscale('log')

plt.title('Bode plot van de meetopstelling')
plt.xlabel('F_vloer (Hz)')
plt.ylabel('(A_out / A_in)')
plt.show()

# %%
# Bereken hier de minimale Delta-x waarbij je aan de eis van de opdracht voldoet.
dx=9.81/(2*np.pi*f_eigenfrequentie)**2
print(dx,'m')
# Out:
# 0.039758432461253344 m

# %%
#simulatie voor boven minamle dx zitten> 

dxgekozen=1.5*dx
fgekozen=np.sqrt(9.81/dxgekozen)/(2*np.pi)

#overdracht formule: 
overdrachtgekozen = np.abs(1 / (1 - (f_vloer/fgekozen)**2))

plt.plot(f_vloer, overdrachtgekozen)

plt.xscale('log')
plt.yscale('log')

plt.title('Bode plot van de meetopstelling')
plt.xlabel('F_vloer (Hz)')
plt.ylabel('(A_out / A_in)')
plt.show()

# %% [markdown]
# ## Opdracht 3: Plot de grafiek.

# %%
# Voeg hier je plot in. Lees goed de opdracht wat er in de grafiek moet staan!
# Het is ook handig om je grafiek op te slaan, doe dat door met plt.savefig().

# Plot van massa tegen veerconstante met de berekende deltax als constante en dan 3 grafieken om zoiezo boven minimale delta x waarde te zitten wegens onnaunwuekruoghedne (afweging nog maken)

g = 9.81  # Valversnelling

massa = np.linspace(0.1, 2.0, 100)

#Massa, veer formule uit eigenfruentie formule met krachtenbalans voor massa veer syteem zonder demping:
C1 = (massa * g) / dx          
C2 = (massa * g) / (2 * dx)    
C3 = (massa * g) / (5 * dx)   
C4 = (massa * g) / (1.5 * dx) 

plt.figure(figsize=(10, 6))
plt.plot(massa, C1, label = 'Minimale dx')
plt.plot(massa, C2, label = '2x dx')
plt.plot(massa, C3, label = '5x dx')
plt.plot(massa, C4, label = '1.5x dx')

plt.title('Massa tegen veerconstante')
plt.xlabel('M $kg$')
plt.ylabel('C $N/m$')
plt.grid(True)
plt.legend()
plt.savefig('Massa_tegen_veerconstante')
plt.show()

# %% [markdown]
# ## Opdracht 4: Verander $\Delta x$.

# %% [markdown]
# We kunnen $\Delta x$ verhogen door:
#
# - kleinere veerconstante
# - grotere massa
#
# Vul onderstaande aan. Geef eventueel met tekst aan waarom je hiervoor gekozen hebt, als extra informatie richting de nakijkers.
#
# Als groep gaan we mikken op een $\Delta x$ van: 6 cm

# %% [markdown]
# ## Opdracht 5: Schets.

# %% [markdown]
# ##### schets opstelling:
# <img src="Schetsen.jpeg" width="400">

# %% [markdown]
# ## Opdracht 6: Beslissing evaluatie

# %% [markdown]
# Voldoet je ontwerp aan de eisen? Beantwoord de volgende vragen:
#
# ### Wat is de $\Delta x$ van je ontwerp?
#
# 6 cm
#
# ### Wordt die $\Delta x$ behaald met je gekozen massa en veer?
#
# Met de panty als veer en druktape als massa wordt de dx uitrekking behaald.
#
# ### hoeveel verder kan je massa-veer systeem nog uitrekken / indrukken?
# Wat is de limiet aan je veer / verend materiaal voordat het niet meer lineair reageert volgens de wet van Hooke?
#
# 10 cm
#
# ### Is dat genoeg om straks metingen te kunnen doen?
# Hou er rekening mee dat je trillingen een amplitude in de orde grote van een paar centimeter gaan hebben, minder is met deze opzet moeilijk te realiseren.
#
# ja
#
# ### Gaat je ontwerp dus voldoen aan de eis?
#
# ja
#
# Als je hier positief geantwoord heb, maak dan nog een keer een plot van amplitude overdracht (y-as) versus frequentie (x-as) zoals je hierboven ook al een keer gedaan heb, maar plot nu twee verschillende overdrachten in de grafiek: één die je al had: behorende bij de grens van de ontwerp-eis en één behorende bij je eigen ontwerp. Lees af dat je voor je ontwerp daadwerkelijk onder de eis grafiek zit op de kritieke frequentie!
#
# Deze grafiek heb je later weer nodig om je gemeten punten aan toe te voegen. Ga daarna je massa-veer systeem daadwerkelijk bouwen.
#
# Als je hier negatief geantwoord hebt, kopieer onder deze cel dan alle cellen van Synthese tot en met Evaluation & decision en doorloop dat deel van het ontwerp proces nogmaals.

# %%
print(fgekozen)
# Out:
# 2.041241452319315

# %% [markdown]
# ## Opdracht 7: Plotten maar

# %%
f_vloer_echt = np.array([1,3,4,5,6,7]) #Hz

#Eigenfrequentie voor minimale dx

#overdrachtminimaal7 = np.abs(1 / (1 - (f_vloer_echt/f_eigenfrequentie)**2))

#Eigenfrequentie voor gekoen dx dus 1.5 dx

#overdrachtgekozen = np.abs(1 / (1 - (f_vloer_echt/fgekozen)**2))

#Echte meting

overdrachtecht = np.abs(1 / (1 - (f_vloer_echt/fgekozen)**2))

Agroen = np.array([0.38, 0.52, 0.51, 0.49, 0.60, 0.43]) #massa
Arood = np.array([0.30, 1.87, 3.01, 3.25, 4.68, 5.01])#vloer

overdrachtgemeten = Agroen/Arood

error_x = (np.array([0.10,0.10,0.25,0.25,0.30,0.50]))
error_y = (np.array([0.3,0.33,0.4,0.60,0.8,0.83]))/2

plt.plot(f_vloer_echt, overdrachtecht, label = 'overdracht volgens theorie bij genomen freuqnetie')
plt.errorbar(f_vloer_echt, overdrachtgemeten, xerr=error_x , yerr=error_y, fmt = '.', label ='overdracht volgens arudino bij genomen feuqnetie')
#plt.plot(f_vloer_echt, overdrachtgekozen, label= 'eigenfreuqntie die is gekozen') 
#plt.plot(f_vloer_echt,overdrachtminimaal7, label ='eigenfreqnetie volgens theorie'  )
plt.plot(f_vloer, overdrachtgekozen,label= 'eigenfreuqntie die is gekozen')
plt.plot(f_vloer, overdrachtminimaal,label ='eigenfreqnetie volgens theorie')
plt.legend()

plt.xscale('log')
plt.yscale('log')
plt.title('Bode plot van de meetopstelling')
plt.xlabel('F_vloer (Hz)')
plt.ylabel('(A_out / A_in)')
plt.xlim()
plt.ylim(10**-2,10**4)
plt.savefig('Bode_plot_van_de_meetopstelling')
plt.show()

# %% [markdown]
# Iteraties:
# 1. Bij idee 1 is een panty as veer gebruikt. Maar de panty dempte niet genoeg en de opstelling resoneerde te veel mee.
#
# 2. Toen is de panty vervangen met elastieken waar en bakje aan vastzat. Dat bakje hield de sensor en het gewicht vast.
#
# 3. Daarna is de onzekerheid van de sensor op de vloer verkleind door de arm van de vloer korter te maken. En ook door gewicht op vloer te zetten.

# %% [markdown]
# ## Opdracht 8: Leerdoelen
# Voeg hieronder zelf kopjes toe om aan te geven wat bij welk leerdoel hoort.

# %%
# Als je met Python je resultaten wil laten zien: voeg hier je code in.

# %% [markdown]
# #### Als je je figuren onderweg opgeslagen hebt, kan je ze hier invoegen:
# Leerdoel 1: Inzien dat de parameters in een differentiaalvergelijking ontwerpparameters zijn die een ontwerpruimte opspannen.
#
# ![Massa tegen veerconstante](Massa_tegen_veerconstante.png)
#
# Leerdoel 2: Op basis van een differentiaal vergelijking een keuze maken voor parameters en die vervolgens kunnen vertalen in een fysiek ontwerp.
#
# ![Bode plot van de meetopstelling](Bode_plot_van_de_meetopstelling.png)
#
# ![Opstelling](Opstelling.jpeg)
